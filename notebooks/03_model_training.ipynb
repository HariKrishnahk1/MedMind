# %% [markdown]
# # 03. Model Training & Leakage Prevention
# ## Clinical Deterioration Prediction Engine Prototype
#
# Demonstrates leak-free patient-level splitting and classifier training.

# %%
import sys
import os
sys.path.insert(0, os.path.abspath('..'))

from src.models.train import train_all_models

# Execute training pipeline
artifacts = train_all_models(processed_dataset_path='../data/processed/model_dataset.csv', models_dir='../models')
print("Training Complete:", artifacts)
